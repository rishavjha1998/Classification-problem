# %%
 import numpy as np
 import pandas as pd
 import matplotlib.pyplot as plt
 import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\risha\\Desktop\\online_Fraud_detection.csv")

# %%
df
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT    9839.64  C1231006815      170136.00
# 1           1   PAYMENT    1864.28  C1666544295       21249.00
# 2           1  TRANSFER     181.00  C1305486145         181.00
# 3           1  CASH_OUT     181.00   C840083671         181.00
# 4           1   PAYMENT   11668.14  C2048537720       41554.00
# ...       ...       ...        ...          ...            ...
# 1048570    95  CASH_OUT  132557.35  C1179511630      479803.00
# 1048571    95   PAYMENT    9917.36  C1956161225       90545.00
# 1048572    95   PAYMENT   14140.05  C2037964975       20545.00
# 1048573    95   PAYMENT   10020.05  C1633237354       90605.00
# 1048574    95   PAYMENT   11450.03  C1264356443       80584.95
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   step            1048575 non-null  int64
#  1   type            1048575 non-null  object
#  2   amount          1048575 non-null  float64
#  3   nameOrig        1048575 non-null  object
#  4   oldbalanceOrg   1048575 non-null  float64
#  5   newbalanceOrig  1048575 non-null  float64
#  6   nameDest        1048575 non-null  object
#  7   oldbalanceDest  1048575 non-null  float64
#  8   newbalanceDest  1048575 non-null  float64
#  9   isFraud         1048575 non-null  int64
#  10  isFlaggedFraud  1048575 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 88.0+ MB

# %%
df_null=df.isnull()
df_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   step            1048575 non-null  bool
#  1   type            1048575 non-null  bool
#  2   amount          1048575 non-null  bool
#  3   nameOrig        1048575 non-null  bool
#  4   oldbalanceOrg   1048575 non-null  bool
#  5   newbalanceOrig  1048575 non-null  bool
#  6   nameDest        1048575 non-null  bool
#  7   oldbalanceDest  1048575 non-null  bool
#  8   newbalanceDest  1048575 non-null  bool
#  9   isFraud         1048575 non-null  bool
#  10  isFlaggedFraud  1048575 non-null  bool
# dtypes: bool(11)
# memory usage: 11.0 MB

# %%
# data is already clean

# %%
# Handling the categorical variable

# %%
sns.barplot(x='type',y='isFraud',data=df)
plt.show()

# %% [markdown]
# # There is clear difference that type determines the fraudlent transaction

# %%
df['nameOrig'].unique().shape # this has no few values so we can remove it as no effect on target
# Out:
# (1048317,)

# %%
df.drop(labels='nameOrig',axis=1,inplace=True)

# %%
df
# Out:
#          step      type     amount  oldbalanceOrg  newbalanceOrig  \
# 0           1   PAYMENT    9839.64      170136.00       160296.36
# 1           1   PAYMENT    1864.28       21249.00        19384.72
# 2           1  TRANSFER     181.00         181.00            0.00
# 3           1  CASH_OUT     181.00         181.00            0.00
# 4           1   PAYMENT   11668.14       41554.00        29885.86
# ...       ...       ...        ...            ...             ...
# 1048570    95  CASH_OUT  132557.35      479803.00       347245.65
# 1048571    95   PAYMENT    9917.36       90545.00        80627.64
# 1048572    95   PAYMENT   14140.05       20545.00         6404.95
# 1048573    95   PAYMENT   10020.05       90605.00        80584.95
# 1048574    95   PAYMENT   11450.03       80584.95        69134.92
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0        M1979787155            0.00            0.00        0               0
# ...

# %%
df['nameDest'].unique().shape
# Out:
# (449635,)

# %%
df.drop(labels='nameDest',axis=1,inplace=True)

df.drop(labels='isFlaggedFraud',axis=1,inplace=True)
df.drop(labels='step',axis=1,inplace=True)

# %%
df
# Out:
#              type     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         PAYMENT    9839.64      170136.00       160296.36            0.00
# 1         PAYMENT    1864.28       21249.00        19384.72            0.00
# 2        TRANSFER     181.00         181.00            0.00            0.00
# 3        CASH_OUT     181.00         181.00            0.00        21182.00
# 4         PAYMENT   11668.14       41554.00        29885.86            0.00
# ...           ...        ...            ...             ...             ...
# 1048570  CASH_OUT  132557.35      479803.00       347245.65       484329.37
# 1048571   PAYMENT    9917.36       90545.00        80627.64            0.00
# 1048572   PAYMENT   14140.05       20545.00         6404.95            0.00
# 1048573   PAYMENT   10020.05       90605.00        80584.95            0.00
# 1048574   PAYMENT   11450.03       80584.95        69134.92            0.00
#
#          newbalanceDest  isFraud
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
type_data=encoder.fit_transform(df['type'])

# %%
df['type'].unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
df.drop(labels='type',axis=1,inplace=True)

# %%
df.insert(1,'type',type_data)

# %%
df
# Out:
#             amount  type  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0          9839.64     3      170136.00       160296.36            0.00
# 1          1864.28     3       21249.00        19384.72            0.00
# 2           181.00     4         181.00            0.00            0.00
# 3           181.00     1         181.00            0.00        21182.00
# 4         11668.14     3       41554.00        29885.86            0.00
# ...            ...   ...            ...             ...             ...
# 1048570  132557.35     1      479803.00       347245.65       484329.37
# 1048571    9917.36     3       90545.00        80627.64            0.00
# 1048572   14140.05     3       20545.00         6404.95            0.00
# 1048573   10020.05     3       90605.00        80584.95            0.00
# 1048574   11450.03     3       80584.95        69134.92            0.00
#
#          newbalanceDest  isFraud
# 0                  0.00        0
# 1                  0.00        0
# ...

# %%
# we can't do correlation in classification problem

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression(multi_class='multinomial', solver='lbfgs')

# %%
LR.fit(X_train,y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
from sklearn.model_selection import cross_val_score

# %%
n_scores = cross_val_score(LR, df.iloc[:,:-1], df.iloc[:,-1])

# %%
n_scores
# Out:
# array([0.99919891, 0.99939918, 0.9992609 , 0.9994421 , 0.99943733])

# %%
n_scores.mean()
# Out:
# 0.9993476861454832

# %%
import pickle

# %%
pickle_out = open("model.pkl", "wb")

# %%
pickle.dump(LR, pickle_out)
pickle_out.close()
